# %% [markdown]
# # 第2章: UNIXコマンド
# popular-names.txtは，アメリカで生まれた赤ちゃんの「名前」「性別」「人数」「年」をタブ区切り形式で格納したファイルである．以下の処理を行うプログラムを作成し，popular-names.txtを入力ファイルとして実行せよ．さらに，同様の処理をUNIXコマンドでも実行し，プログラムの実行結果を確認せよ．

# %% [markdown]
# ## 10. 行数のカウント
# 行数をカウントせよ．確認にはwcコマンドを用いよ．

# %%
count = 0
contents = None

with open('popular-names.txt', 'r') as f:
    contents =  f.read().split('\n')
    count = len(contents)
    
print(count)

# 確認コマンド ws -l popular-names.txt
# Out:
# 2780

# %% [markdown]
# ## 11. タブをスペースに置換
# タブ1文字につきスペース1文字に置換せよ．確認にはsedコマンド，trコマンド，もしくはexpandコマンドを用いよ．

# %%
exchanged_contents = [ content.replace('\t', ' ') for content in contents ]
print(exchanged_contents[0:3])
# Out:
# ['Mary F 7065 1880', 'Anna F 2604 1880', 'Emma F 2003 1880']

# %% [markdown]
# ## 12. 1列目をcol1.txtに，2列目をcol2.txtに保存
# 各行の1列目だけを抜き出したものをcol1.txtに，2列目だけを抜き出したものをcol2.txtとしてファイルに保存せよ．確認にはcutコマンドを用いよ．

# %%
col1 = '\n'.join([ row.split(' ')[0] for row in exchanged_contents ])
with open('./col1.txt', 'w') as f:
    f.write(col1)

col2 = '\n'.join([ row.split(' ')[1] for row in exchanged_contents ])
with open('./col2.txt', 'w') as f:
    f.write(col2)

# %% [markdown]
# ## 13. col1.txtとcol2.txtをマージ
# 12で作ったcol1.txtとcol2.txtを結合し，元のファイルの1列目と2列目をタブ区切りで並べたテキストファイルを作成せよ．確認にはpasteコマンドを用いよ．

# %%
col1 = None
col2 = None

with open('./col1.txt', 'r') as f:
    col1 = f.read().split('\n')

with open('./col2.txt', 'r') as f:
    col2 = f.read().split('\n')

with open('./col1and2.txt', 'w') as f:
    col1and2 = '\n'.join([ one + '\t' + two  for one, two in zip(col1, col2) ])
    f.write(col1and2)

# %% [markdown]
# ## 14. 先頭からN行を出力
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のうち先頭のN行だけを表示せよ．確認にはheadコマンドを用いよ．

# %%
with open('./col1and2.txt', 'r') as f:
    col1and2 = f.read().split('\n')

n = count + 1
while n > count:
    n = int(input('please enter your favaorite number'))

print(col1and2[0:n])
# Out:
# please enter your favaorite number10
# ['Mary\tF', 'Anna\tF', 'Emma\tF', 'Elizabeth\tF', 'Minnie\tF', 'Margaret\tF', 'Ida\tF', 'Alice\tF', 'Bertha\tF', 'Sarah\tF']

# %% [markdown]
# ## 15. 末尾のN行を出力
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のうち末尾のN行だけを表示せよ．確認にはtailコマンドを用いよ．

# %%
n = count + 1
while n > count:
    n = int(input('please enter your favaorite number'))

print(col1and2[-n:])
# Out:
# please enter your favaorite number10
# ['Liam\tM', 'Noah\tM', 'William\tM', 'James\tM', 'Oliver\tM', 'Benjamin\tM', 'Elijah\tM', 'Lucas\tM', 'Mason\tM', 'Logan\tM']

# %% [markdown]
# ## 16. ファイルをN分割するPermalink
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のファイルを行単位でN分割せよ．同様の処理をsplitコマンドで実現せよ．

# %%
n = count + 1
while n > count:
    n = int(input('please enter your favaorite number'))
# Out:
# please enter your favaorite number100

# %% [markdown]
# ## 17. １列目の文字列の異なり
# 1列目の文字列の種類（異なる文字列の集合）を求めよ．確認にはcut, sort, uniqコマンドを用いよ．

# %%
set_col1 = set(col1)
print(set_col1)
print(len(set_col1))
# Out:
# {'Megan', 'Hannah', 'Florence', 'Alice', 'Larry', 'Harry', 'Lucas', 'Karen', 'Pamela', 'Minnie', 'Jessica', 'Christopher', 'Ethel', 'Deborah', 'Daniel', 'Donna', 'Abigail', 'Madison', 'Jeffrey', 'Andrew', 'Tammy', 'Joan', 'Kathleen', 'Tracy', 'Elijah', 'Mason', 'Angela', 'Joseph', 'Steven', 'Thomas', 'Betty', 'Annie', 'Kelly', 'Jason', 'Brandon', 'Crystal', 'Isabella', 'Ashley', 'Cynthia', 'Heather', 'James', 'Amelia', 'Mia', 'Melissa', 'Lisa', 'Austin', 'Michael', 'Anthony', 'Susan', 'Sharon', 'Ruth', 'Jennifer', 'Nicholas', 'Shirley', 'Bertha', 'Stephanie', 'Chloe', 'Jayden', 'Justin', 'Barbara', 'Sarah', 'Gary', 'Henry', 'Debra', 'Brian', 'Scott', 'Ava', 'Lillian', 'Charles', 'Linda', 'Sophia', 'Oliver', 'Margaret', 'Mary', 'Rebecca', 'Nicole', 'Nancy', 'Emily', 'Richard', 'Aiden', 'Lori', 'Jacob', 'Olivia', 'Doris', 'Clara', 'Michelle', 'Logan', 'Dorothy', 'Sandra', 'Robert', 'Kimberly', 'Liam', 'Laura', 'Judith', 'Mildred', 'Noah', 'Donald', 'Brittany', 'Samantha', 'Harper', 'Wa
# ...

# %% [markdown]
# ## 18. 各行を3コラム目の数値の降順にソート
# 各行を3コラム目の数値の逆順で整列せよ（注意: 各行の内容は変更せずに並び替えよ）．確認にはsortコマンドを用いよ（この問題はコマンドで実行した時の結果と合わなくてもよい）．

# %%
sorted(exchanged_contents, key=lambda x: int(x.split(' ')[2]), reverse=True)
# Out:
# ['Linda F 99689 1947',
#  'Linda F 96211 1948',
#  'James M 94757 1947',
#  'Michael M 92704 1957',
#  'Robert M 91640 1947',
#  'Linda F 91016 1949',
#  'Michael M 90656 1956',
#  'Michael M 90517 1958',
#  'James M 88584 1948',
#  'Michael M 88528 1954',
#  'Michael M 88327 1955',
#  'John M 88319 1947',
#  'James M 87436 1946',
#  'James M 87261 1951',
#  'James M 87063 1952',
#  'Michael M 86917 1961',
#  'James M 86857 1949',
#  'Robert M 86604 1952',
#  'Robert M 86351 1951',
#  'Robert M 86298 1954',
#  'James M 86272 1954',
#  'Robert M 86256 1953',
#  'David M 86253 1955',
#  'James M 86224 1950',
#  'James M 86099 1953',
#  'David M 85929 1960',
#  'Robert M 85475 1948',
#  'Michael M 85302 1970',
#  'Michael M 85251 1959',
#  'Michael M 85203 1969',
#  'Michael M 85034 1962',
#  'James M 84863 1956',
#  'David M 84758 1961',
#  'James M 84275 1957',
#  'Michael M 84226 1953',
#  'Michael M 84180 1960',
#  'James M 84155 1955',
#  'Robert M 84138 1946',
# ...

# %% [markdown]
# ## 19. 各行の1コラム目の文字列の出現頻度を求め，出現頻度の高い順に並べる
# 各行の1列目の文字列の出現頻度を求め，その高い順に並べて表示せよ．確認にはcut, uniq, sortコマンドを用いよ．

# %%
import collections

sorted(collections.Counter(col1).items(), key=lambda x: x[1], reverse=True)
# Out:
# [('James', 118),
#  ('William', 111),
#  ('John', 108),
#  ('Robert', 108),
#  ('Mary', 92),
#  ('Charles', 75),
#  ('Michael', 74),
#  ('Elizabeth', 73),
#  ('Joseph', 70),
#  ('Margaret', 60),
#  ('George', 58),
#  ('Thomas', 58),
#  ('David', 57),
#  ('Richard', 51),
#  ('Helen', 45),
#  ('Frank', 43),
#  ('Christopher', 43),
#  ('Anna', 41),
#  ('Edward', 40),
#  ('Ruth', 39),
#  ('Patricia', 38),
#  ('Matthew', 37),
#  ('Dorothy', 36),
#  ('Emma', 35),
#  ('Barbara', 32),
#  ('Daniel', 31),
#  ('Joshua', 31),
#  ('Sarah', 26),
#  ('Linda', 26),
#  ('Jennifer', 26),
#  ('Emily', 26),
#  ('Jessica', 25),
#  ('Jacob', 25),
#  ('Mildred', 24),
#  ('Betty', 24),
#  ('Susan', 24),
#  ('Henry', 23),
#  ('Ashley', 23),
#  ('Nancy', 22),
#  ('Andrew', 21),
#  ('Florence', 20),
#  ('Marie', 20),
#  ('Donald', 20),
#  ('Amanda', 20),
#  ('Samantha', 19),
#  ('Karen', 18),
#  ('Lisa', 18),
#  ('Melissa', 18),
#  ('Madison', 18),
#  ('Olivia', 18),
#  ('Stephanie', 17),
#  ('Abigail', 17),
# ...
