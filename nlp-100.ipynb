# %% [markdown]
# # 第１章: 準備運動

# %% [markdown]
# ### 00. 文字列の逆順
# 文字列”stressed”の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ

# %%
str = "stressed"
reverse_str = ""

for i in range(1, len(str)+1):
    reverse_str += str[-i]

print(reverse_str)

print(str[::-1])
# Out:
# desserts
# desserts

# %% [markdown]
# ## 01. 「パタトクカシーー」
# 「パタトクカシーー」という文字列の1,3,5,7文字目を取り出して連結した文字列を得よ

# %%
str01 = "パタトクカシーー"
print(str01[1::2])
# Out:
# タクシー

# %% [markdown]
# ## 02. 「パトカー」＋「タクシー」＝「パタトクカシーー」
# 「パトカー」＋「タクシー」の文字を先頭から交互に連結して文字列「パタトクカシーー」を得よ．

# %%
str02_1 = "パトカー"
str02_2 = "タクシー"
connected_str = ""

for i in range(0, len(str02_1)):
    connected_str += str02_1[i] + str02_2[i]
    
print(connected_str)
# Out:
# パタトクカシーー

# %% [markdown]
# ## 03. 円周率
# “Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.”という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ．

# %%
str03 = 'Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.'
str03_list = str03.split(' ')

print([len(str.replace(',', '').replace('.', '')) for str in str03_list])
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ## 04. 元素記号
# “Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.”という文を単語に分解し，1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字，それ以外の単語は先頭の2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ．

# %%
str04 = 'Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.'
char_index_list = [1, 5, 6, 7, 8, 9, 15, 16, 19]
element_dict = {}

for index, word in enumerate(str04.split(' ')):
    key = word[0] if index + 1 in char_index_list else word[0:2]
    element_dict[key] = index
    
print(element_dict)
# Out:
# {'H': 0, 'He': 1, 'Li': 2, 'Be': 3, 'B': 4, 'C': 5, 'N': 6, 'O': 7, 'F': 8, 'Ne': 9, 'Na': 10, 'Mi': 11, 'Al': 12, 'Si': 13, 'P': 14, 'S': 15, 'Cl': 16, 'Ar': 17, 'K': 18, 'Ca': 19}

# %% [markdown]
# ## 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ．この関数を用い，”I am an NLPer”という文から単語bi-gram，文字bi-gramを得よ．

# %%
def n_gram(n, sentence):
    return [sentence[ i : i+n ] for i in range(len(sentence))]

str05 = 'I am an NLPer'

# bi-gram
print(n_gram(2, str05))

# TODO: 単語bi-gramと文字bi-gramがよくわからんので確認してから実装する
# Out:
# ['I ', ' a', 'am', 'm ', ' a', 'an', 'n ', ' N', 'NL', 'LP', 'Pe', 'er', 'r']

# %% [markdown]
# ## 06. 集合
# “paraparaparadise”と”paragraph”に含まれる文字bi-gramの集合を，それぞれ, XとYとして求め，XとYの和集合，積集合，差集合を求めよ．さらに，’se’というbi-gramがXおよびYに含まれるかどうかを調べよ.

# %%
str06_1 = 'paraparaparadise'
str06_2 = 'paragraph'

bi_gram_1 = set(n_gram(2, str06_1))
bi_gram_2 = set(n_gram(2, str06_2))

print('X: {}'.format(bi_gram_1))
print('Y: {}'.format(bi_gram_2))

# 和集合 |
print('和集合: {}'.format(bi_gram_1 | bi_gram_2))
# 積集合　&
print('積集合: {}'.format(bi_gram_1 & bi_gram_2))
# 差集合 -
print('差集合: {}'.format(bi_gram_1 - bi_gram_2))

print('se contains X and Y ?: {}'.format('se' in bi_gram_1 & bi_gram_2))
print('se contains X ? : {}'.format('se' in bi_gram_1))
print('se contains Y ? : {}'.format('se' in bi_gram_2))
# Out:
# X: {'is', 'se', 'ra', 'di', 'ad', 'e', 'ar', 'pa', 'ap'}
# Y: {'ra', 'gr', 'h', 'ar', 'ph', 'pa', 'ag', 'ap'}
# 和集合: {'is', 'se', 'ra', 'gr', 'di', 'ad', 'e', 'h', 'ar', 'ph', 'pa', 'ag', 'ap'}
# 積集合: {'pa', 'ap', 'ra', 'ar'}
# 差集合: {'is', 'se', 'di', 'ad', 'e'}
# se contains X and Y ?: False
# se contains X ? : True
# se contains Y ? : False

# %% [markdown]
# ## 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ．さらに，x=12, y=”気温”, z=22.4として，実行結果を確認せよ．

# %%
x = 12
y = '気温'
z = 22.4

str07 = lambda x, y, z: '{}時の{}は{}'.format(x, y, z)
print(str07(x, y, z))
# Out:
# 12時の気温は22.4

# %% [markdown]
# ## 08. 暗号文
# 与えられた文字列の各文字を，以下の仕様で変換する関数cipherを実装せよ．
#
# - 英小文字ならば(219 - 文字コード)の文字に置換
# - その他の文字はそのまま出力
#
# この関数を用い，英語のメッセージを暗号化・復号化せよ．

# %%
def shift(s):
    return chr(219 - ord(s))

def cipher(str):
    return ''.join([ shift(s) if s.islower() else s for s in str])

raw_str = "Hello, nlp100!"
print('raw sentence: {}'.format(raw_str))
encrypted_str = cipher(raw_str)
print('encrypted sentence: {}'.format(encrypted_str))
decrypted_str = cipher(encrypted_str)
print('decrypted sentence: {}'.format(decrypted_str) )
# Out:
# raw sentence: Hello, nlp100!
# encrypted sentence: Hvool, mok100!
# decrypted sentence: Hello, nlp100!

# %% [markdown]
# ## 09. Typoglycemia
# スペースで区切られた単語列に対して，各単語の先頭と末尾の文字は残し，それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ．ただし，長さが４以下の単語は並び替えないこととする．適当な英語の文（例えば”I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .”）を与え，その実行結果を確認せよ．

# %%
str09 = 'I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .'
